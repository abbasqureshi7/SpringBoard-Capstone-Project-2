# %%
import tweepy as tw
consumer_key = "VqcxzBOXycA5eSY4DVh8gdbcN"
consumer_secret = "kLkViKhCJ9VaXAeuvNr2bEBgC5pcYDOi5lwh5vXuTtc0bpL9L7"
access_token = "400927565-O9z7W7ucgL7esDLkRg2e4JSTfiNSTixqlf2tmC7i"
access_token_secret = "Oe2ohU0flKGf1HUn0ZkVTXmJ2tA3IgXCjkyFgo9x75imF"

# %%
import pandas as pd

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret)
#setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
#creating the API object while passing in auth information
api = tw.API(auth, wait_on_rate_limit=True)

# %%
tweets = api.search("@emiratessupport" "-filter:retweets", lang='en',rpp=100)

# %%
[tweet.text for tweet in tweets]
# Out:
# ['@EmiratesSupport why did you outsource your checkin and ground staff at schiphol? The Denate team has seriously dropped your standards',
#  '@EmiratesSupport help I booked flights to Sri Lanka last Tuesday and now the FCO advise no one to travel there, can I get a refund?',
#  '@EmiratesSupport I booked a flight to Sri Lanka in July, following onto the incidents in Sri Lanka, I no longer to… https://t.co/N4nhDLeLSu',
#  '@EmiratesSupport \nNeed a help. Will be travelling from Singapore to London Heathrow/Stansted. What is the baggage a… https://t.co/Xj64gqwx8y',
#  '@PhilipCragg @EmiratesSupport @emirates Please share',
#  "@EmiratesSupport are charging us £300 JUST to change our flights. That's also before a flight difference charge! Ev… https://t.co/MWWBY6jN7K",
#  "@EmiratesSupport I've tried the Emirates office in Bahrain my wife ended up crying with the manager refusing to com… https://t.co/vmp67WNxwl",
#  "@EmiratesSupport Why are Emirates cashing in on the terrorism in Sri Lanka? We've tried to change our flights to Sr… https://t.co/nPNBpCX90C",
#  '@EmiratesSupport We have already sent claims into the link you gave us and have been ignored numerous times . Your… https://t.co/KCxS9IxJ7H',
#  'Hi @EmiratesSupport - Live chat not working, can we get some help knowing our baggage allowance please?',
#  '@EmiratesSupport hi please could someone assist me, I’ve been asked to pay £150 to receive a refund for my flights to Sri Lanka?',
#  '@EmiratesSupport Emigrating from Scotland to Australia with @emirates in May, flight cost £900 for 2 people- extra… https://t.co/U8LGjbV6Qp',
#  '@EmiratesSupport Sent you a dm',
#  "@EmiratesSupport please kindly help with reference number 437, it's a parcel from London. I want to know if it has arrived Abuja. Thank you.",
#  "Kindly @EmiratesSupport check your DM please, it's urgent."]

# %%
user_tweets = [[tweet.user.screen_name, tweet.text] for tweet in tweets]
user_tweets
# Out:
# [['ChrisSavides',
#   '@EmiratesSupport why did you outsource your checkin and ground staff at schiphol? The Denate team has seriously dropped your standards'],
#  ['BelleeScaaarlet',
#   '@EmiratesSupport help I booked flights to Sri Lanka last Tuesday and now the FCO advise no one to travel there, can I get a refund?'],
#  ['Janammoorthy',
#   '@EmiratesSupport I booked a flight to Sri Lanka in July, following onto the incidents in Sri Lanka, I no longer to… https://t.co/N4nhDLeLSu'],
#  ['RanitRoyChowdh',
#   '@EmiratesSupport \nNeed a help. Will be travelling from Singapore to London Heathrow/Stansted. What is the baggage a… https://t.co/Xj64gqwx8y'],
#  ['MarketingHE', '@PhilipCragg @EmiratesSupport @emirates Please share'],
#  ['KerrySiddons',
#   "@EmiratesSupport are charging us £300 JUST to change our flights. That's also before a flight difference charge! Ev… https://t.co/MWWBY6jN7K"],
#  ['HEBusiness',
#   "@EmiratesSupport I've tried the Emirates office in Bahrain my wife ended up crying with the manager refusing to com… https://t.co/vmp67WNxwl"],
#  ['HEBusiness',
#   "@EmiratesSupport Why are Emirates cashing in on the terrorism in Sri Lanka? We've tried to change our flights to Sr… https://t.co/nPNBpCX90C"],
#  ['Carolin29708064',
#   '@EmiratesSupport We have already sent claims into the link you gave us and have been ignored numerous times . Your… https://t.co/KCxS9IxJ7H'],
#  ['oRoseyo',
#   'Hi @EmiratesSupport - Live chat not working, can we get some help knowing our baggage allowance please?'],
#  ['GregorHMitchell',
#   '@EmiratesSupport hi please could someone assist me, I’ve been asked to pay £150 to receive a refund for my flights to Sri Lanka?'],
#  ['carty_sarahlou',
#   '@EmiratesSupport Emigrating from Scotland to Australia with @emirates in May, flight cost £900 for 2 people- extra… https://t.co/U8LGjbV6Qp'],
#  ['amh382', '@EmiratesSupport Sent you a dm'],
#  ['GovernorJepsy7',
#   "@EmiratesSupport please kindly help with reference number 437, it's a parcel from London. I want to know if it has arrived Abuja. Thank you."],
#  ['GovernorJepsy7',
#   "Kindly @EmiratesSupport check your DM please, it's urgent."]]

# %%
tweet_text = pd.DataFrame(data=user_tweets,
                         columns= ['User', 'Tweet'])

tweet_text
# Out:
#                User  \
# 0   ChrisSavides
# 1   BelleeScaaarlet
# 2   Janammoorthy
# 3   RanitRoyChowdh
# 4   MarketingHE
# 5   KerrySiddons
# 6   HEBusiness
# 7   HEBusiness
# 8   Carolin29708064
# 9   oRoseyo
# 10  GregorHMitchell
# 11  carty_sarahlou
# 12  amh382
# 13  GovernorJepsy7
# 14  GovernorJepsy7
#
#                                                                                                                                             Tweet
# 0   @EmiratesSupport why did you outsource your checkin and ground staff at schiphol? The Denate team has seriously dropped your standards
# 1   @EmiratesSupport help I booked flights to Sri Lanka last Tuesday and now the FCO advise no one to travel there, can I get a refund?
# 2   @EmiratesSupport I booked a flight to Sri Lanka in July, following onto the incidents in Sri Lanka, I no longer to… https://t.co/N4nhDLeLSu
# 3   @EmiratesSupport \nNeed a help. Will be travelling from Singapore to London Heathrow/Stansted. What is the baggage a… https://t.co/Xj64gqwx8y
# 4   @PhilipCragg @EmiratesSupport @emirates Please share
# 5   @EmiratesSupport are charging us £300 JUST to change our flights. That's also before a flight difference charge! Ev… https://t.co/MWWBY6jN7K
# 6   @EmiratesSupport I've tried the Emirates office in Bahrain my wife ended up crying with the manager refusing to com… https://t.co/vmp67WNxwl
# 7   @EmiratesSupport Why are Emirates cashing in on the terrorism in Sri Lanka? We've tried to change our flights to Sr… https://t.co/nPNBpCX90C
# 8   @EmiratesSupport We have already sent claims into the link you gave us and have been ignored numerous times . Your… https://t.co/KCxS9IxJ7H
# 9   Hi @EmiratesSupport - Live chat not working, can we get some help knowing our baggage allowance please?
# 10  @EmiratesSupport hi please could someone assist me, I’ve been asked to pay £150 to receive a refund for my flights to Sri Lanka?
# 11  @EmiratesSupport Emigrating from Scotland to Australia with @emirates in May, flight cost £900 for 2 people- extra… https://t.co/U8LGjbV6Qp
# 12  @EmiratesSupport Sent you a dm
# 13  @EmiratesSupport please kindly help with reference number 437, it's a parcel from London. I want to know if it has arrived Abuja. Thank you.
# 14  Kindly @EmiratesSupport check your DM please, it's urgent.

# %%
pd.set_option('display.max_colwidth', -1)

# %%
tweet_text
# Out:
#                User  \
# 0   ChrisSavides
# 1   BelleeScaaarlet
# 2   Janammoorthy
# 3   RanitRoyChowdh
# 4   MarketingHE
# 5   KerrySiddons
# 6   HEBusiness
# 7   HEBusiness
# 8   Carolin29708064
# 9   oRoseyo
# 10  GregorHMitchell
# 11  carty_sarahlou
# 12  amh382
# 13  GovernorJepsy7
# 14  GovernorJepsy7
#
#                                                                                                                                             Tweet
# 0   @EmiratesSupport why did you outsource your checkin and ground staff at schiphol? The Denate team has seriously dropped your standards
# 1   @EmiratesSupport help I booked flights to Sri Lanka last Tuesday and now the FCO advise no one to travel there, can I get a refund?
# 2   @EmiratesSupport I booked a flight to Sri Lanka in July, following onto the incidents in Sri Lanka, I no longer to… https://t.co/N4nhDLeLSu
# 3   @EmiratesSupport \nNeed a help. Will be travelling from Singapore to London Heathrow/Stansted. What is the baggage a… https://t.co/Xj64gqwx8y
# 4   @PhilipCragg @EmiratesSupport @emirates Please share
# 5   @EmiratesSupport are charging us £300 JUST to change our flights. That's also before a flight difference charge! Ev… https://t.co/MWWBY6jN7K
# 6   @EmiratesSupport I've tried the Emirates office in Bahrain my wife ended up crying with the manager refusing to com… https://t.co/vmp67WNxwl
# 7   @EmiratesSupport Why are Emirates cashing in on the terrorism in Sri Lanka? We've tried to change our flights to Sr… https://t.co/nPNBpCX90C
# 8   @EmiratesSupport We have already sent claims into the link you gave us and have been ignored numerous times . Your… https://t.co/KCxS9IxJ7H
# 9   Hi @EmiratesSupport - Live chat not working, can we get some help knowing our baggage allowance please?
# 10  @EmiratesSupport hi please could someone assist me, I’ve been asked to pay £150 to receive a refund for my flights to Sri Lanka?
# 11  @EmiratesSupport Emigrating from Scotland to Australia with @emirates in May, flight cost £900 for 2 people- extra… https://t.co/U8LGjbV6Qp
# 12  @EmiratesSupport Sent you a dm
# 13  @EmiratesSupport please kindly help with reference number 437, it's a parcel from London. I want to know if it has arrived Abuja. Thank you.
# 14  Kindly @EmiratesSupport check your DM please, it's urgent.

# %%
tweet_text.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
# User     15 non-null object
# Tweet    15 non-null object
# dtypes: object(2)
# memory usage: 320.0+ bytes
